# %%
# %matplotlib inline
import json
from pathlib import Path

import matplotlib.pyplot as plt

LOG = Path("train_log.jsonl")
steps, losses = [], []
for line in LOG.read_text(encoding="utf-8").splitlines():
    line = line.strip()
    if not line:
        continue
    row = json.loads(line)
    steps.append(row["step"])
    losses.append(row["loss"])

plt.figure(figsize=(8, 4))
plt.plot(steps, losses)
plt.xlabel("step")
plt.ylabel("loss")
plt.grid(True, alpha=0.3)
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
categories = ['Group 1', 'Group 2']
means = [98, 95]
errors = [5, 6]  # 标准差或标准误

# 创建图表
fig, ax = plt.subplots(figsize=(6, 5))
colors = ['#F4C430', '#A8B8C0']  # 黄色和灰蓝色

bars = ax.bar(categories, means, yerr=errors, capsize=5, 
              color=colors, edgecolor='black', linewidth=1.5,
              error_kw={'elinewidth': 1.5, 'capthick': 1.5})

# 设置样式
ax.set_ylabel('成功率（%）', fontsize=12)
ax.set_title('洗衣（T恤和短裤）', fontsize=14, pad=20)
ax.set_ylim(0, 110)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\gonghao\AppData\Local\Temp\ipykernel_7152\2250899090.py:24: UserWarning: Glyph 25104 (\N{CJK UNIFIED IDEOGRAPH-6210}) missing from current font.
#   plt.tight_layout()
# C:\Users\gonghao\AppData\Local\Temp\ipykernel_7152\2250899090.py:24: UserWarning: Glyph 21151 (\N{CJK UNIFIED IDEOGRAPH-529F}) missing from current font.
#   plt.tight_layout()
# C:\Users\gonghao\AppData\Local\Temp\ipykernel_7152\2250899090.py:24: UserWarning: Glyph 29575 (\N{CJK UNIFIED IDEOGRAPH-7387}) missing from current font.
#   plt.tight_layout()
# C:\Users\gonghao\AppData\Local\Temp\ipykernel_7152\2250899090.py:24: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# C:\Users\gonghao\AppData\Local\Temp\ipykernel_7152\2250899090.py:24: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   plt.tight_layout()
# C:\Users\gonghao\AppData\Local\Temp\ipykernel_7152\2250899090.py:24: UserWarning: Glyph 27927 (\N{CJK UNIFIED IDEOGRAPH-6D17}) missing from current font.
#   plt.tight_layout()
# C:\Users\gonghao\AppData\Local\Temp\ipykernel_7152\2250899090.py:24: UserWarning: Glyph 34915 (\N{CJK UNIFIED IDEOGRAPH-8863}) missing from current font.
#   plt.tight_layout()
# C:\Users\gonghao\AppData\Local\Temp\ipykernel_7152\2250899090.py:24: UserWarning: Glyph 24676 (\N{CJK UNIFIED IDEOGRAPH-6064}) missing from current font.
#   plt.tight_layout()
# C:\Users\gonghao\AppData\Local\Temp\ipykernel_7152\2250899090.py:24: UserWarning: Glyph 21644 (\N{CJK UNIFIED IDEOGRAPH-548C}) missing from current font.
#   plt.tight_layout()
# C:\Users\gonghao\AppData\Local\Temp\ipykernel_7152\2250899090.py:24: UserWarning: Glyph 30701 (\N{CJK UNIFIED IDEOGRAPH-77ED}) missing from current font.
#   plt.tight_layout()
# C:\Users\gonghao\AppData\Local\Temp\ipykernel_7152\2250899090.py:24: UserWarning: Glyph 35044 (\N{CJK UNIFIED IDEOGRAPH-88E4}) missing from current font.
#   plt.tight_layout()
# d:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 25104 (\N{CJK UNIFIED IDEOGRAPH-6210}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21151 (\N{CJK UNIFIED IDEOGRAPH-529F}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 29575 (\N{CJK UNIFIED IDEOGRAPH-7387}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 65288 (\N{FULLWIDTH LEFT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 65289 (\N{FULLWIDTH RIGHT PARENTHESIS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 27927 (\N{CJK UNIFIED IDEOGRAPH-6D17}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 34915 (\N{CJK UNIFIED IDEOGRAPH-8863}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 24676 (\N{CJK UNIFIED IDEOGRAPH-6064}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 21644 (\N{CJK UNIFIED IDEOGRAPH-548C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 30701 (\N{CJK UNIFIED IDEOGRAPH-77ED}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# d:\anaconda\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 35044 (\N{CJK UNIFIED IDEOGRAPH-88E4}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
